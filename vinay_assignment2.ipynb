# %% [markdown]
# <a href="https://colab.research.google.com/github/vinaysk125/vinayassingment/blob/main/vinay_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Querying a Data Frame

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/content/train-200907-141856.csv')
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
dataset['Name'].head()
# dataset.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
dataset['Age'].min()
# Out:
# 0.42

# %%
dataset['Age'].max()
# Out:
# 80.0

# %%
dataset['Age'].mean()
# Out:
# 29.69911764705882

# %%
dataset.loc[0:10, 'Name']
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
dataset.loc[0:10, 'Name':'Ticket']
# Out:
#                                                  Name  ...            Ticket
# 0                             Braund, Mr. Owen Harris  ...         A/5 21171
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  ...          PC 17599
# 2                              Heikkinen, Miss. Laina  ...  STON/O2. 3101282
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  ...            113803
# 4                            Allen, Mr. William Henry  ...            373450
# 5                                    Moran, Mr. James  ...            330877
# 6                             McCarthy, Mr. Timothy J  ...             17463
# 7                      Palsson, Master. Gosta Leonard  ...            349909
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  ...            347742
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  ...            237736
# 10                    Sandstrom, Miss. Marguerite Rut  ...           PP 9549
#
# [11 rows x 6 columns]

# %%
dataset.iloc[0:10, 3:9]
# Out:
#                                                 Name  ...            Ticket
# 0                            Braund, Mr. Owen Harris  ...         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  ...          PC 17599
# 2                             Heikkinen, Miss. Laina  ...  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  ...            113803
# 4                           Allen, Mr. William Henry  ...            373450
# 5                                   Moran, Mr. James  ...            330877
# 6                            McCarthy, Mr. Timothy J  ...             17463
# 7                     Palsson, Master. Gosta Leonard  ...            349909
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  ...            347742
# 9                Nasser, Mrs. Nicholas (Adele Achem)  ...            237736
#
# [10 rows x 6 columns]

# %%
# Print the name of the oldest passenger travelling on ship
dataset[dataset['Age'] == dataset['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
dataset.sort_values(by='Name').head()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 845          846         0       3  ...   7.55   NaN         S
# 746          747         0       3  ...  20.25   NaN         S
# 279          280         1       3  ...  20.25   NaN         S
# 308          309         0       2  ...  24.00   NaN         C
# 874          875         1       2  ...  24.00   NaN         C
#
# [5 rows x 12 columns]

# %%
dataset.sort_values(by=['Name', 'Fare'], ascending=[True, False]).head()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 845          846         0       3  ...   7.55   NaN         S
# 746          747         0       3  ...  20.25   NaN         S
# 279          280         1       3  ...  20.25   NaN         S
# 308          309         0       2  ...  24.00   NaN         C
# 874          875         1       2  ...  24.00   NaN         C
#
# [5 rows x 12 columns]

# %%
new = {'male':0, 'female':1}
dataset = dataset.replace({'Sex':new})
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0            1         0       3  ...   7.2500    NaN         S
# 1            2         1       1  ...  71.2833    C85         C
# 2            3         1       3  ...   7.9250    NaN         S
# 3            4         1       1  ...  53.1000   C123         S
# 4            5         0       3  ...   8.0500    NaN         S
#
# [5 rows x 12 columns]

# %%
old = {0:'male', 1:'female'}
dataset['Sex'] = dataset['Sex'].map(old)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
dataset.groupby(by='Survived')['Age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0         424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1         290.0  28.343690  14.950952  0.42  19.0  28.0  36.0  80.0

# %%
dataset.groupby(by='Embarked')['Age'].agg(np.mean)
# Out:
# Embarked
# C    30.814769
# Q    28.089286
# S    29.445397
# Name: Age, dtype: float64

# %%
pd.crosstab(dataset['Survived'], dataset['Sex'], normalize=True)
# Out:
# Sex         female      male
# Survived
# 0         0.090909  0.525253
# 1         0.261504  0.122334

# %%
dataset.pivot_table(['Age', 'Fare'],['Survived'])
# Out:
#                 Age       Fare
# Survived
# 0         30.626179  22.117887
# 1         28.343690  48.395408
